# %% [markdown]
# # Import Libraries

# %%
#Exploratory Data Analysis (EDA)
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Load the dataset
df = pd.read_csv('AirPassengers.csv')
df.head(5)
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.shape
# Out:
# (144, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %% [markdown]
# The data contains a particular month and number of passengers travelling in that month .

# %% [markdown]
# # Data Preprocessing

# %%
#Convert it into a Time series object and use the Month column as our index.
df['Month'] = pd.to_datetime(df['Month'])
df.set_index('Month', inplace=True)

# %%
#check datatype of index
df.index
# Out:
# DatetimeIndex(['1949-01-01', '1949-02-01', '1949-03-01', '1949-04-01',
#                '1949-05-01', '1949-06-01', '1949-07-01', '1949-08-01',
#                '1949-09-01', '1949-10-01',
#                ...
#                '1960-03-01', '1960-04-01', '1960-05-01', '1960-06-01',
#                '1960-07-01', '1960-08-01', '1960-09-01', '1960-10-01',
#                '1960-11-01', '1960-12-01'],
#               dtype='datetime64[ns]', name='Month', length=144, freq=None)

# %%
#convert to time series:
tdf = df['#Passengers']
tdf.head(10)
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# 1949-06-01    135
# 1949-07-01    148
# 1949-08-01    148
# 1949-09-01    136
# 1949-10-01    119
# Name: #Passengers, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
#Visualize time series data
#checking stationarity
plt.figure(figsize=(10, 6))
plt.plot(df)
plt.title('Airline Passenger Data')
plt.xlabel('Year')
plt.ylabel('Passengers (in thousands)')
plt.show()

# %% [markdown]
# **The plot unmistakably reveals a consistent upward trend with noticeable seasonal patterns. There is signinficant upward trend in the pattern.**

# %%
#Plotting the rolling mean

# Define the rolling window size (e.g., 12 for monthly data)
rolling_window = 12

# Calculate rolling mean and rolling standard deviation
rolling_mean = df['#Passengers'].rolling(window=rolling_window).mean()
rolling_std = df['#Passengers'].rolling(window=rolling_window).std()

# Plot the original data
plt.figure(figsize=(10, 6))
plt.plot(df['#Passengers'], label='Original Data')

# Plot rolling mean
plt.plot(rolling_mean, label='Rolling Mean', color='red')

# Plot rolling standard deviation
plt.plot(rolling_std, label='Rolling Std', color='green')

plt.title('Rolling Statistics of AirPassengers')
plt.xlabel('Year')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
# Perform the Dickey-Fuller test
print('Dickey-Fuller Test:')
dftest = adfuller(tdf, autolag='AIC')

# Create a Series to display the test results
dfoutput = pd.Series({
    'Test Statistic': dftest[0],
    'p-value': dftest[1],
    '#Lags Used': dftest[2],
    'Number of Observations Used': dftest[3]
})

# Display the critical values
for key, value in dftest[4].items():
    dfoutput[f'Critical Value ({key})'] = value

print(dfoutput)
# Out:
# Dickey-Fuller Test:
# Test Statistic                   0.815369
# p-value                          0.991880
# #Lags Used                      13.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %% [markdown]
# **In the preceding chart, it's evident that the rolling mean exhibits a discernible trend, while the rolling standard deviation remains relatively consistent over time. The critical values are notably distant from the Test Statistics. Consequently, we can conclude that, for the current period, our Time Series does not display stationarity. From the above ADCF test result, we can see that p-value(near to 1.0) is very large. Also critical values are no where close to the Test Statistics. Hence, we can safely say that our Time Series at the moment is NOT STATIONARY**

# %%
import statsmodels.tsa.api as smt
fig, axes = plt.subplots(1, 2)
fig.set_figwidth(12)
fig.set_figheight(4)
smt.graphics.plot_acf(df, lags=40, ax=axes[0])
smt.graphics.plot_pacf(df, lags=40, ax=axes[1])
plt.tight_layout()

# %%
df["year"]=[d.year for d in df.index]
df["month"]=[d.strftime('%b') for d in df.index]

# %%
df.head(2)
# Out:
#             #Passengers  year month
# Month
# 1949-01-01          112  1949   Jan
# 1949-02-01          118  1949   Feb

# %%
import seaborn as sns
sns.boxplot(x='year',y='#Passengers',data=df)
# Out:
# <Axes: xlabel='year', ylabel='#Passengers'>

# %%
sns.boxplot(x='month',y='#Passengers',data=df)
# Out:
# <Axes: xlabel='month', ylabel='#Passengers'>

# %% [markdown]
# **There are no outliers in the data**

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposed=seasonal_decompose(df["#Passengers"],
                             model='additive'
                             )

# %%
trend=decomposed.trend
sesonal=decomposed.seasonal
residual=decomposed.resid

# %%
plt.figure(figsize=(12,8))
plt.subplot(411)
plt.plot(df["#Passengers"],label="Orginal",color='blue')
plt.legend(loc='upper left')
plt.subplot(412)
plt.plot(trend,label="Trend",color='blue')
plt.legend(loc='upper left')
plt.subplot(413)
plt.plot(sesonal,label="Sesonal",color='blue')
plt.legend(loc='upper left')
plt.subplot(414)
plt.plot(residual,label="Residual",color='blue')
plt.legend(loc='upper left')
plt.show()

# %%
# Check for missing values
missing_values = df.isnull().sum()
# Handle missing values if any
missing_values
# Out:
# #Passengers    0
# year           0
# month          0
# dtype: int64

# %% [markdown]
# **There are no null values in thge dataset**

# %% [markdown]
# # Data Scaling

# %%
#Data Preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

# Normalize the data
scaler = MinMaxScaler()
df['#Passengers'] = scaler.fit_transform(df[['#Passengers']])

# %%
df.head(5)
# Out:
#             #Passengers  year month
# Month
# 1949-01-01     0.015444  1949   Jan
# 1949-02-01     0.027027  1949   Feb
# 1949-03-01     0.054054  1949   Mar
# 1949-04-01     0.048263  1949   Apr
# 1949-05-01     0.032819  1949   May

# %%
df.shape
# Out:
# (144, 3)

# %% [markdown]
# # Convert the time series into a supervised learning

# %%
import numpy as np

# Convert the time series into a supervised learning problem
def create_supervised_dataset(data, n_in=6, n_out=1):
    X, y = [], []
    for i in range(len(data) - n_in - n_out + 1):
        X.append(data[i:(i + n_in)])
        y.append(data[(i + n_in):(i + n_in + n_out)])
    return np.array(X), np.array(y)

n_in = 6
n_out = 1

# %%
X, y = create_supervised_dataset(df['#Passengers'].values, n_in, n_out)

# %%
X.shape
# Out:
# (138, 6)

# %% [markdown]
# # Test Train Split

# %%
# Split the data into training and test sets based on the index
train_end = np.where(df.index == pd.Timestamp(year=1958, month=12, day=1))[0][0]
test_start = train_end + 1

# Given the time_step, adjust the indices to get the correct split
train_end -= n_in - 1
test_start -= n_in

X_train, X_test = X[:train_end], X[test_start:]
y_train, y_test = y[:train_end], y[test_start:]

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (114, 6)
# (114, 1)
# (24, 6)
# (24, 1)

# %%
# Reshape input to be [samples, time steps, features] which is required for LSTM/RNN
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

print(f'Train shape: {X_train.shape}')
print(f'Test shape: {X_test.shape}')
# Out:
# Train shape: (114, 6, 1)
# Test shape: (24, 6, 1)

# %% [markdown]
# # Training Model

# %%
# Step 3: Architecture Selection using Keras
from keras.models import Sequential
from keras.layers import SimpleRNN, Dense
from keras.optimizers import Adam

model = Sequential()
model.add(SimpleRNN(units=64, activation='relu', input_shape=(n_in, 1)))
model.add(Dense(units=1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer=Adam(learning_rate=0.001))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 64)                4224
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 4289 (16.75 KB)
# Trainable params: 4289 (16.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Step 4: Training
from keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True)
checkpoint = ModelCheckpoint('best_model.h5', save_best_only=True)

history = model.fit(X_train, y_train, epochs=1000, batch_size=32, verbose=1, validation_data=(X_test, y_test), callbacks=[early_stopping, checkpoint])
# Out:
# Epoch 1/1000
# 4/4 [==============================] - 2s 159ms/step - loss: 0.0391 - val_loss: 0.0727
# Epoch 2/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0125 - val_loss: 0.0214
# Epoch 3/1000
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0065
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0080 - val_loss: 0.0216
# Epoch 4/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0075 - val_loss: 0.0158
# Epoch 5/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0047 - val_loss: 0.0197
# Epoch 6/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0052 - val_loss: 0.0197
# Epoch 7/1000
# 4/4 [==============================] - 0s 23ms/step - loss: 0.0045 - val_loss: 0.0153
# Epoch 8/1000
# 4/4 [==============================] - 0s 29ms/step - loss: 0.0043 - val_loss: 0.0137
# Epoch 9/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0043 - val_loss: 0.0130
# Epoch 10/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0037 - val_loss: 0.0133
# Epoch 11/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0038 - val_loss: 0.0129
# Epoch 12/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0036 - val_loss: 0.0112
# Epoch 13/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0034 - val_loss: 0.0106
# Epoch 14/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0033 - val_loss: 0.0105
# Epoch 15/1000
# 4/4 [==============================] - 0s 30ms/step - loss: 0.0033 - val_loss: 0.0104
# Epoch 16/1000
# 4/4 [==============================] - 0s 35ms/step - loss: 0.0032 - val_loss: 0.0097
# Epoch 17/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0030 - val_loss: 0.0100
# Epoch 18/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0030 - val_loss: 0.0109
# Epoch 19/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0029 - val_loss: 0.0100
# Epoch 20/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0030 - val_loss: 0.0093
# Epoch 21/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0028 - val_loss: 0.0108
# Epoch 22/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0029 - val_loss: 0.0108
# Epoch 23/1000
# 4/4 [==============================] - 0s 21ms/step - loss: 0.0027 - val_loss: 0.0091
# Epoch 24/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0027 - val_loss: 0.0088
# Epoch 25/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0026 - val_loss: 0.0094
# Epoch 26/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0026 - val_loss: 0.0088
# Epoch 27/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0025 - val_loss: 0.0085
# Epoch 28/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0025 - val_loss: 0.0087
# Epoch 29/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0025 - val_loss: 0.0077
# Epoch 30/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0024 - val_loss: 0.0078
# Epoch 31/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0023 - val_loss: 0.0079
# Epoch 32/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0022 - val_loss: 0.0081
# Epoch 33/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0023 - val_loss: 0.0085
# Epoch 34/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0022 - val_loss: 0.0073
# Epoch 35/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0023 - val_loss: 0.0079
# Epoch 36/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0023 - val_loss: 0.0067
# Epoch 37/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0020 - val_loss: 0.0079
# Epoch 38/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0021 - val_loss: 0.0080
# Epoch 39/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0067
# Epoch 40/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0020 - val_loss: 0.0066
# Epoch 41/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0020 - val_loss: 0.0072
# Epoch 42/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0019 - val_loss: 0.0075
# Epoch 43/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0019 - val_loss: 0.0067
# Epoch 44/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0019 - val_loss: 0.0064
# Epoch 45/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0018 - val_loss: 0.0058
# Epoch 46/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0018 - val_loss: 0.0060
# Epoch 47/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0071
# Epoch 48/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0018 - val_loss: 0.0065
# Epoch 49/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0017 - val_loss: 0.0060
# Epoch 50/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 0.0062
# Epoch 51/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0017 - val_loss: 0.0059
# Epoch 52/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.0063
# Epoch 53/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.0062
# Epoch 54/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0016 - val_loss: 0.0054
# Epoch 55/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0016 - val_loss: 0.0058
# Epoch 56/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0016 - val_loss: 0.0060
# Epoch 57/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0016 - val_loss: 0.0058
# Epoch 58/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0015 - val_loss: 0.0053
# Epoch 59/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0015 - val_loss: 0.0048
# Epoch 60/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 0.0015 - val_loss: 0.0055
# Epoch 61/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0015 - val_loss: 0.0060
# Epoch 62/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0015 - val_loss: 0.0052
# Epoch 63/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0049
# Epoch 64/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0057
# Epoch 65/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0057
# Epoch 66/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0014 - val_loss: 0.0047
# Epoch 67/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0055
# Epoch 68/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0053
# Epoch 69/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0014 - val_loss: 0.0051
# Epoch 70/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0051
# Epoch 71/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 0.0014 - val_loss: 0.0054
# Epoch 72/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0050
# Epoch 73/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 0.0014 - val_loss: 0.0049
# Epoch 74/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0014 - val_loss: 0.0058
# Epoch 75/1000
# 4/4 [==============================] - 0s 27ms/step - loss: 0.0014 - val_loss: 0.0045
# Epoch 76/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 0.0013 - val_loss: 0.0045
# Epoch 77/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 0.0043
# Epoch 78/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0013 - val_loss: 0.0048
# Epoch 79/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 0.0013 - val_loss: 0.0052
# Epoch 80/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 0.0012 - val_loss: 0.0048
# Epoch 81/1000
# 4/4 [==============================] - 0s 32ms/step - loss: 0.0013 - val_loss: 0.0045
# Epoch 82/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0012 - val_loss: 0.0048
# Epoch 83/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0044
# Epoch 84/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0012 - val_loss: 0.0045
# Epoch 85/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 86/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 87/1000
# 4/4 [==============================] - 0s 31ms/step - loss: 0.0012 - val_loss: 0.0041
# Epoch 88/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0012 - val_loss: 0.0044
# Epoch 89/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0047
# Epoch 90/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0012 - val_loss: 0.0040
# Epoch 91/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 92/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 0.0011 - val_loss: 0.0043
# Epoch 93/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 0.0011 - val_loss: 0.0042
# Epoch 94/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0011 - val_loss: 0.0045
# Epoch 95/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0011 - val_loss: 0.0046
# Epoch 96/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 0.0011 - val_loss: 0.0039
# Epoch 97/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 0.0010 - val_loss: 0.0046
# Epoch 98/1000
# 4/4 [==============================] - 0s 28ms/step - loss: 0.0010 - val_loss: 0.0041
# Epoch 99/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 9.9553e-04 - val_loss: 0.0041
# Epoch 100/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 9.7451e-04 - val_loss: 0.0045
# Epoch 101/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0010 - val_loss: 0.0043
# Epoch 102/1000
# 4/4 [==============================] - 0s 22ms/step - loss: 9.7211e-04 - val_loss: 0.0037
# Epoch 103/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 9.9662e-04 - val_loss: 0.0044
# Epoch 104/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 9.6399e-04 - val_loss: 0.0042
# Epoch 105/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 9.3188e-04 - val_loss: 0.0038
# Epoch 106/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 9.6108e-04 - val_loss: 0.0041
# Epoch 107/1000
# 4/4 [==============================] - 0s 26ms/step - loss: 9.6249e-04 - val_loss: 0.0036
# Epoch 108/1000
# 4/4 [==============================] - 0s 21ms/step - loss: 9.2818e-04 - val_loss: 0.0039
# Epoch 109/1000
# 4/4 [==============================] - 0s 25ms/step - loss: 9.0929e-04 - val_loss: 0.0041
# Epoch 110/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 9.1308e-04 - val_loss: 0.0038
# Epoch 111/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 8.7187e-04 - val_loss: 0.0038
# Epoch 112/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 8.8265e-04 - val_loss: 0.0040
# Epoch 113/1000
# 4/4 [==============================] - 0s 23ms/step - loss: 8.8329e-04 - val_loss: 0.0040
# Epoch 114/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 8.5200e-04 - val_loss: 0.0039
# Epoch 115/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 8.6313e-04 - val_loss: 0.0040
# Epoch 116/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 8.5592e-04 - val_loss: 0.0038
# Epoch 117/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 8.3873e-04 - val_loss: 0.0042
# Epoch 118/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 8.4683e-04 - val_loss: 0.0032
# Epoch 119/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 8.0632e-04 - val_loss: 0.0041
# Epoch 120/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 8.9936e-04 - val_loss: 0.0041
# Epoch 121/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 7.9732e-04 - val_loss: 0.0034
# Epoch 122/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 7.7186e-04 - val_loss: 0.0038
# Epoch 123/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 8.0441e-04 - val_loss: 0.0035
# Epoch 124/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 7.8083e-04 - val_loss: 0.0031
# Epoch 125/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 7.6721e-04 - val_loss: 0.0035
# Epoch 126/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 7.5113e-04 - val_loss: 0.0036
# Epoch 127/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 7.4560e-04 - val_loss: 0.0037
# Epoch 128/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 7.3755e-04 - val_loss: 0.0034
# Epoch 129/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 7.2006e-04 - val_loss: 0.0032
# Epoch 130/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 7.0017e-04 - val_loss: 0.0036
# Epoch 131/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 6.9446e-04 - val_loss: 0.0035
# Epoch 132/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 7.3568e-04 - val_loss: 0.0030
# Epoch 133/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 6.9386e-04 - val_loss: 0.0034
# Epoch 134/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 6.7765e-04 - val_loss: 0.0032
# Epoch 135/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 6.5013e-04 - val_loss: 0.0032
# Epoch 136/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 6.2494e-04 - val_loss: 0.0031
# Epoch 137/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 6.2948e-04 - val_loss: 0.0030
# Epoch 138/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 6.0549e-04 - val_loss: 0.0032
# Epoch 139/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 6.2839e-04 - val_loss: 0.0034
# Epoch 140/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 6.6663e-04 - val_loss: 0.0033
# Epoch 141/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 6.6339e-04 - val_loss: 0.0038
# Epoch 142/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 7.3077e-04 - val_loss: 0.0040
# Epoch 143/1000
# 4/4 [==============================] - 0s 24ms/step - loss: 6.6808e-04 - val_loss: 0.0029
# Epoch 144/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 7.0830e-04 - val_loss: 0.0039
# Epoch 145/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 7.9294e-04 - val_loss: 0.0031
# Epoch 146/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 7.0473e-04 - val_loss: 0.0055
# Epoch 147/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 7.1056e-04 - val_loss: 0.0030
# Epoch 148/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 8.5475e-04 - val_loss: 0.0029
# Epoch 149/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 9.1175e-04 - val_loss: 0.0043
# Epoch 150/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 8.2518e-04 - val_loss: 0.0027
# Epoch 151/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 7.8815e-04 - val_loss: 0.0031
# Epoch 152/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 7.0340e-04 - val_loss: 0.0036
# Epoch 153/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 7.1029e-04 - val_loss: 0.0045
# Epoch 154/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 7.6106e-04 - val_loss: 0.0032
# Epoch 155/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 6.9964e-04 - val_loss: 0.0032
# Epoch 156/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 6.2339e-04 - val_loss: 0.0035
# Epoch 157/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 6.7481e-04 - val_loss: 0.0027
# Epoch 158/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 6.6732e-04 - val_loss: 0.0030
# Epoch 159/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 7.5485e-04 - val_loss: 0.0032
# Epoch 160/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 7.4062e-04 - val_loss: 0.0031
# Epoch 161/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 6.4877e-04 - val_loss: 0.0031
# Epoch 162/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 5.5057e-04 - val_loss: 0.0030
# Epoch 163/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 5.6743e-04 - val_loss: 0.0030
# Epoch 164/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 5.4451e-04 - val_loss: 0.0029
# Epoch 165/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 5.2999e-04 - val_loss: 0.0033
# Epoch 166/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 5.3245e-04 - val_loss: 0.0026
# Epoch 167/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 4.7763e-04 - val_loss: 0.0028
# Epoch 168/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 4.4881e-04 - val_loss: 0.0027
# Epoch 169/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 4.7066e-04 - val_loss: 0.0029
# Epoch 170/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 4.7719e-04 - val_loss: 0.0029
# Epoch 171/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 5.0507e-04 - val_loss: 0.0027
# Epoch 172/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 4.5331e-04 - val_loss: 0.0030
# Epoch 173/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 4.9650e-04 - val_loss: 0.0027
# Epoch 174/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 4.4265e-04 - val_loss: 0.0027
# Epoch 175/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 3.9488e-04 - val_loss: 0.0034
# Epoch 176/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 4.5625e-04 - val_loss: 0.0027
# Epoch 177/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 5.8195e-04 - val_loss: 0.0033
# Epoch 178/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 6.4117e-04 - val_loss: 0.0036
# Epoch 179/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 5.7148e-04 - val_loss: 0.0031
# Epoch 180/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 5.0523e-04 - val_loss: 0.0033
# Epoch 181/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 5.0073e-04 - val_loss: 0.0031
# Epoch 182/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 4.5018e-04 - val_loss: 0.0026
# Epoch 183/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 4.4100e-04 - val_loss: 0.0029
# Epoch 184/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 4.6450e-04 - val_loss: 0.0026
# Epoch 185/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 4.8846e-04 - val_loss: 0.0032
# Epoch 186/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 5.2938e-04 - val_loss: 0.0028
# Epoch 187/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 4.9120e-04 - val_loss: 0.0031
# Epoch 188/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 5.5566e-04 - val_loss: 0.0032
# Epoch 189/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 6.9087e-04 - val_loss: 0.0033
# Epoch 190/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 4.8009e-04 - val_loss: 0.0033
# Epoch 191/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 5.2616e-04 - val_loss: 0.0030
# Epoch 192/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 5.2479e-04 - val_loss: 0.0028
# Epoch 193/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 4.2751e-04 - val_loss: 0.0029
# Epoch 194/1000
# 4/4 [==============================] - 0s 11ms/step - loss: 5.0174e-04 - val_loss: 0.0028
# Epoch 195/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 4.1462e-04 - val_loss: 0.0027
# Epoch 196/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 3.5670e-04 - val_loss: 0.0026
# Epoch 197/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 3.8855e-04 - val_loss: 0.0027
# Epoch 198/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 3.4010e-04 - val_loss: 0.0026
# Epoch 199/1000
# 4/4 [==============================] - 0s 17ms/step - loss: 3.5919e-04 - val_loss: 0.0026
# Epoch 200/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 3.5719e-04 - val_loss: 0.0028
# Epoch 201/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 3.3652e-04 - val_loss: 0.0026
# Epoch 202/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 3.2729e-04 - val_loss: 0.0028
# Epoch 203/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 3.4558e-04 - val_loss: 0.0026
# Epoch 204/1000
# 4/4 [==============================] - 0s 20ms/step - loss: 3.2243e-04 - val_loss: 0.0027
# Epoch 205/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 3.1888e-04 - val_loss: 0.0026
# Epoch 206/1000
# 4/4 [==============================] - 0s 18ms/step - loss: 3.0699e-04 - val_loss: 0.0025
# Epoch 207/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 3.4437e-04 - val_loss: 0.0026
# Epoch 208/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 3.5056e-04 - val_loss: 0.0029
# Epoch 209/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 3.3518e-04 - val_loss: 0.0026
# Epoch 210/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 3.5574e-04 - val_loss: 0.0027
# Epoch 211/1000
# 4/4 [==============================] - 0s 19ms/step - loss: 3.5021e-04 - val_loss: 0.0025
# Epoch 212/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 3.5054e-04 - val_loss: 0.0024
# Epoch 213/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 3.1354e-04 - val_loss: 0.0025
# Epoch 214/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 3.1207e-04 - val_loss: 0.0025
# Epoch 215/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.8619e-04 - val_loss: 0.0025
# Epoch 216/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.9061e-04 - val_loss: 0.0027
# Epoch 217/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 2.9861e-04 - val_loss: 0.0025
# Epoch 218/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.8235e-04 - val_loss: 0.0027
# Epoch 219/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.6963e-04 - val_loss: 0.0028
# Epoch 220/1000
# 4/4 [==============================] - 0s 15ms/step - loss: 2.7667e-04 - val_loss: 0.0026
# Epoch 221/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.7867e-04 - val_loss: 0.0026
# Epoch 222/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.6673e-04 - val_loss: 0.0025
# Epoch 223/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 2.6872e-04 - val_loss: 0.0026
# Epoch 224/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 2.5941e-04 - val_loss: 0.0028
# Epoch 225/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 2.5649e-04 - val_loss: 0.0026
# Epoch 226/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.5337e-04 - val_loss: 0.0027
# Epoch 227/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 2.8671e-04 - val_loss: 0.0025
# Epoch 228/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.7360e-04 - val_loss: 0.0027
# Epoch 229/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 2.7432e-04 - val_loss: 0.0024
# Epoch 230/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.6424e-04 - val_loss: 0.0027
# Epoch 231/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.5868e-04 - val_loss: 0.0026
# Epoch 232/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.4860e-04 - val_loss: 0.0028
# Epoch 233/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.5677e-04 - val_loss: 0.0026
# Epoch 234/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.7177e-04 - val_loss: 0.0025
# Epoch 235/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.8295e-04 - val_loss: 0.0028
# Epoch 236/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.7001e-04 - val_loss: 0.0027
# Epoch 237/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.6944e-04 - val_loss: 0.0030
# Epoch 238/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.5714e-04 - val_loss: 0.0027
# Epoch 239/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 2.8096e-04 - val_loss: 0.0028
# Epoch 240/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 3.0180e-04 - val_loss: 0.0024
# Epoch 241/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.5634e-04 - val_loss: 0.0026
# Epoch 242/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.5515e-04 - val_loss: 0.0028
# Epoch 243/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.7161e-04 - val_loss: 0.0026
# Epoch 244/1000
# 4/4 [==============================] - 0s 14ms/step - loss: 2.9628e-04 - val_loss: 0.0034
# Epoch 245/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 3.1918e-04 - val_loss: 0.0027
# Epoch 246/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 3.5539e-04 - val_loss: 0.0031
# Epoch 247/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.9009e-04 - val_loss: 0.0027
# Epoch 248/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 2.9916e-04 - val_loss: 0.0033
# Epoch 249/1000
# 4/4 [==============================] - 0s 13ms/step - loss: 3.0821e-04 - val_loss: 0.0030
# Epoch 250/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.8165e-04 - val_loss: 0.0032
# Epoch 251/1000
# 4/4 [==============================] - 0s 12ms/step - loss: 2.9840e-04 - val_loss: 0.0027
# Epoch 252/1000
# 4/4 [==============================] - 0s 16ms/step - loss: 2.8301e-04 - val_loss: 0.0028

# %%
from keras.models import load_model
# Step 5: Evaluation
from sklearn.metrics import mean_squared_error,mean_absolute_error

# Load the best model
best_model = load_model('best_model.h5')

# %% [markdown]
# # Evaluation

# %%
# Predict on test set
y_pred = best_model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 182ms/step

# %%
# Calculate MSE
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error (MSE): {mse}')
mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Squared Error (MAE): {mae}')
# Out:
# Mean Squared Error (MSE): 0.0023810503192906456
# Mean Squared Error (MAE): 0.039263714689814135

# %% [markdown]
# **After all the model architectural experiments and hyper-parameter tuning I got best results with Means squered error of ~0.0023 and Mean absolute error of 0.039**

# %%
# Visualize Prediction Results

# Set subplot subtitles
titles = ['RNN']

# Create a list of prediction models
models = [y_pred]

# Set the plot area
fig, ax = plt.subplots(1, 1, figsize=(16,4), tight_layout=True)

# Set the title
plt.suptitle('Airline Passenger Forecasting')

# Create and show subplots
for i in range(0, 1):
    plt.subplot(1, 1,i+1)
    plt.title(titles[i], fontsize=10)
    plt.plot(y_test, label='N of Passengers')
    plt.plot(models[i], label=titles[i]+' Prediction')
    plt.legend()
    plt.xlabel('Time')
    plt.ylabel('N of Passengers')

# %% [markdown]
# **The predicted values closely align with the underlying trend observed in the original dataset.**

# %%
# Plot the learning history
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(loc='best')
plt.ylim([0,0.05])
plt.show()

# %% [markdown]
# **As the number of epochs increases, the loss decreases, as indicated by the downward trend in the graph.**

# %% [markdown]
# # Save Results

# %%
import pandas as pd
y_pred_rescaled = scaler.inverse_transform(y_pred)
predictions = pd.DataFrame({'Month': df.index[-len(y_test):], 'Passengers': y_pred_rescaled.flatten().astype(int)})
predictions.to_csv('predictions.csv', index=False)
